# %% [markdown]
# # 1. Clusterização Hierárquica

# %%
# import libraries

# linear algebra
import numpy as np 
# data processing
import pandas as pd 
# library of math
import math
# data visualization
from matplotlib import pyplot as plt 
# datasets
from sklearn import datasets

# %%
# Scikit Learning hierarchical clustering
from sklearn.cluster import AgglomerativeClustering
# SciPy hierarchical clustering
from scipy.cluster import hierarchy

# %% [markdown]
# ## 1.1 Clusterização Hierárquica

# %% [markdown]
# Verifique abaixo o resultado da clusterização hierárquica variando a quantidade de clusters de forma iterativa. Teste também outras funções de ligação (linkage).
#
# Fique livre parar alterar ou criar novos dados no dataset de exemplo abaixo.

# %%
# Dataset
tmp_data = np.random.normal(0, 50, (100,2))

plt.scatter(tmp_data[:,0], tmp_data[:,1], s=150)
plt.show()

# %%
# Teste diferentes funções de ligações
# {“ward”, “complete”, “average”}
linkage = 'ward'
linkage_cpt = 'complete'
linkage_avg = 'average'

# Clusterização hierárquica
ag_model = AgglomerativeClustering(linkage=linkage)
ag_model_2 = AgglomerativeClustering(linkage=linkage_cpt)
ag_model_3 = AgglomerativeClustering(linkage=linkage_avg)

# %%
# Número de colunas do plot
plot_col = 3

n_rows = 4
n_col = 3
fig, ax = plt.subplots(nrows=int(n_rows*n_col/plot_col), 
                       ncols=plot_col,figsize=(20,20))

count = 0
for n_clusters in range(2,n_rows*n_col):
    index = abs(n_clusters - 2)
    
    # Atribui o número de clusters
    ag_model.n_clusters = n_clusters
    # Ajusta o modelo
    ag_model = ag_model.fit(tmp_data)
    
    if plot_col == 1:
        ax[count].scatter(tmp_data[:,0], tmp_data[:,1], c=ag_model.labels_, s=150)
        ax[count].set_title("Qt. Clusters: " + str(n_clusters))
    else:
        ax[count, (index)%plot_col].scatter(tmp_data[:,0], tmp_data[:,1], c=ag_model.labels_, s=150)
        ax[count, (index)%plot_col].set_title("Qt. Clusters: " + str(n_clusters))
    
    if (index+1) % plot_col == 0:
        count += 1     

print("/************************************************** WARD *************************************************************/")
plt.show()
# Out:
# /************************************************** WARD *************************************************************/

# %%
# Número de colunas do plot
plot_col = 3

n_rows = 4
n_col = 3
fig, ax = plt.subplots(nrows=int(n_rows*n_col/plot_col), 
                       ncols=plot_col,figsize=(20,20))

count = 0
for n_clusters in range(2,n_rows*n_col):
    index = abs(n_clusters - 2)
    
    # Atribui o número de clusters
    ag_model_2.n_clusters = n_clusters
    # Ajusta o modelo
    ag_model_2 = ag_model_2.fit(tmp_data)
    
    if plot_col == 1:
        ax[count].scatter(tmp_data[:,0], tmp_data[:,1], c=ag_model_2.labels_, s=150)
        ax[count].set_title("Qt. Clusters: " + str(n_clusters))
    else:
        ax[count, (index)%plot_col].scatter(tmp_data[:,0], tmp_data[:,1], c=ag_model_2.labels_, s=150)
        ax[count, (index)%plot_col].set_title("Qt. Clusters: " + str(n_clusters))
    
    if (index+1) % plot_col == 0:
        count += 1     

print("/************************************************** COMPLETE *********************************************************/")
plt.show()
# Out:
# /************************************************** COMPLETE *********************************************************/

# %%
# Número de colunas do plot
plot_col = 3

n_rows = 4
n_col = 3
fig, ax = plt.subplots(nrows=int(n_rows*n_col/plot_col), 
                       ncols=plot_col,figsize=(20,20))

count = 0
for n_clusters in range(2,n_rows*n_col):
    index = abs(n_clusters - 2)
    
    # Atribui o número de clusters
    ag_model_3.n_clusters = n_clusters
    # Ajusta o modelo
    ag_model_3 = ag_model_3.fit(tmp_data)
    
    if plot_col == 1:
        ax[count].scatter(tmp_data[:,0], tmp_data[:,1], c=ag_model_3.labels_, s=150)
        ax[count].set_title("Qt. Clusters: " + str(n_clusters))
    else:
        ax[count, (index)%plot_col].scatter(tmp_data[:,0], tmp_data[:,1], c=ag_model_3.labels_, s=150)
        ax[count, (index)%plot_col].set_title("Qt. Clusters: " + str(n_clusters))
    
    if (index+1) % plot_col == 0:
        count += 1     

print("/************************************************** AVERAGE *********************************************************/")
plt.show()
# Out:
# /************************************************** AVERAGE *********************************************************/

# %% [markdown]
# # 1.2 Dendrograma

# %% [markdown]
# Um dendrograma é um tipo de diagrama de árvore que mostra o relacionamentos entre conjuntos de dados semelhantes, ou agrupamento hierárquico. Eles são freqüentemente usados em biologia para mostrar o agrupamento entre genes ou amostras, mas podem representar qualquer tipo de dados agrupados.
# > https://www.statisticshowto.datasciencecentral.com/hierarchical-clustering/

# %% [markdown]
# Utilize o código abaixo para criar os Dendrogramas dos dados utilizados nas células acima. Fique livre para retornar e testar outras distribuições dos dados e funções de ligamento (linkage).

# %%
# Usa o método de linkage especificado 
# para construir o dendrograma
if (linkage == 'average'):
    Z = hierarchy.average(tmp_data)
elif (linkage == 'complete'):
    Z = hierarchy.complete(tmp_data)
elif (linkage == 'ward'):
    Z = hierarchy.ward(tmp_data)

plt.figure(figsize=(15,8))
plt.title("Dendrograma - linkage: " + str(linkage))
dn = hierarchy.dendrogram(Z)

# %%
# Usa o método de linkage especificado 
# para construir o dendrograma
linkage = "complete"
if (linkage == 'average'):
    Z = hierarchy.average(tmp_data)
elif (linkage == 'complete'):
    Z = hierarchy.complete(tmp_data)
elif (linkage == 'ward'):
    Z = hierarchy.ward(tmp_data)

plt.figure(figsize=(15,8))
plt.title("Dendrograma - linkage: " + str(linkage))
dn = hierarchy.dendrogram(Z)

# %%
# Usa o método de linkage especificado 
# para construir o dendrograma
linkage = "average"
if (linkage == 'average'):
    Z = hierarchy.average(tmp_data)
elif (linkage == 'complete'):
    Z = hierarchy.complete(tmp_data)
elif (linkage == 'ward'):
    Z = hierarchy.ward(tmp_data)

plt.figure(figsize=(15,8))
plt.title("Dendrograma - linkage: " + str(linkage))
dn = hierarchy.dendrogram(Z)

# %% [markdown]
# É possível fazer um teste de permutação para validar o número de clusters escolhidos, ou seja, verificar se realmente existe uma tendência não aleatória para os objetos se agruparem.
#
# A técnica envolve testes estatísticos e pode ser estudado pelo material a seguir:
# http://www.econ.upf.edu/~michael/stanford/maeb7.pdf

# %% [markdown]
# ## 1.3 Exemplo 1 - Bolhas com diferentes variâncias

# %% [markdown]
# Observe a distribuição do dataset abaixo.

# %%
# blobs with varied variances
n_samples = 1500
random_state = 170
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)
dataset_varied = varied[0]

plt.scatter(dataset_varied[:,0], dataset_varied[:,1])
plt.show()

# %% [markdown]
# Utilize o algoritmo do K-means para separa os conjuntos.
#
# Você pode importar o K-means criado por você! Para importar uma função de um notebook para outro instale a biblioteca nbimporter:

# %%
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

# %%
### CODE HERE ###
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
dataset = np.dot(X, transformation)

# %%
sse = []
for K in range(1, 10):
    model = KMeans(n_clusters=K)
    model.fit(X, transformation)
    sse.append(model.inertia_)

# %%
plt.plot(range(1,10), sse)

# %%
model = KMeans(n_clusters=3)
model = model.fit(X, transformation)

# %%
model.cluster_centers_
# Out:
# array([[-8.94137566, -5.48137132],
#        [ 1.91176144,  0.40634045],
#        [-4.55490993,  0.02920864]])

# %%
list(set(model.labels_))
# Out:
# [0, 1, 2]

# %%
n_samples = 1500
random_state = 170
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)
dataset_varied = varied[0]

plt.scatter(dataset_varied[:,0], dataset_varied[:,1], c=model.labels_)
plt.show()

# %% [markdown]
# Os dados parecem estar agrupados corretamente? Tente fazer o mesmo procedimento com algoritmo de clusterização hieráquica
# > https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html

# %%
### CODE HERE ###
clustering = AgglomerativeClustering(n_clusters=3)
clustering = clustering.fit(X, transformation)

# %%
list(set(clustering.labels_))
# Out:
# [0, 1, 2]

# %%
n_samples = 1500
random_state = 170
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)
dataset_varied = varied[0]

plt.scatter(dataset_varied[:,0], dataset_varied[:,1], c=clustering.labels_)
plt.show()

# %%
# Número de colunas do plot
plot_col = 3

n_rows = 4
n_col = 3
fig, ax = plt.subplots(nrows=int(n_rows*n_col/plot_col), 
                       ncols=plot_col,figsize=(20,20))

count = 0
for n_clusters in range(2,n_rows*n_col):
    index = abs(n_clusters - 2)
    
    # Atribui o número de clusters
    clustering.n_clusters = n_clusters
    # Ajusta o modelo
    clustering = clustering.fit(dataset_varied)
    
    if plot_col == 1:
        ax[count].scatter(dataset_varied[:,0], dataset_varied[:,1], c=clustering.labels_, s=150)
        ax[count].set_title("Qt. Clusters: " + str(n_clusters))
    else:
        ax[count, (index)%plot_col].scatter(dataset_varied[:,0], dataset_varied[:,1], c=clustering.labels_, s=150)
        ax[count, (index)%plot_col].set_title("Qt. Clusters: " + str(n_clusters))
    
    if (index+1) % plot_col == 0:
        count += 1     

print("/************************************************** WARD *************************************************************/")
plt.show()
# Out:
# /************************************************** WARD *************************************************************/

# %% [markdown]
# Mostre e análise o dendrograma do exemplo acima.

# %%
### CODE HERE ###

linkage = ["average", "ward", "complete"]

for i in linkage:
    if (i == 'average'):
        Z = hierarchy.average(dataset_varied)
    elif (i == 'complete'):
        Z = hierarchy.complete(dataset_varied)
    elif (i == 'ward'):
        Z = hierarchy.ward(dataset_varied)

    plt.figure(figsize=(15,8))
    plt.title("Dendrograma - linkage: " + str(i))
    dn = hierarchy.dendrogram(Z)

# %% [markdown]
# Qual a sua conclusão?

# %% [markdown]
# O kmeans consegue separar e identificar coorretamente os clusters.

# %% [markdown]
# ## 1.4 Exemplo 2 - Noisy Circles

# %%
# Gerar o conjunto de dados
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
dataset_circles = noisy_circles[0]

# Mostrar os dados
plt.scatter(dataset_circles[:,0], dataset_circles[:,1])
plt.show()

# %% [markdown]
# Utilize o algoritmo do K-means para separa os conjuntos.

# %%
### CODE HERE ###

sse = []
for K in range(1, 10):
    model = KMeans(n_clusters=K)
    model.fit(X)
    sse.append(model.inertia_)

# %%
plt.plot(range(1,10), sse)

# %%
model_circle = KMeans(n_clusters=4)
model_circle = model_circle.fit(X, transformation)

# %%
model_circle.labels_
# Out:
# array([2, 2, 3, ..., 1, 1, 1])

# %%
model_circle.cluster_centers_
# Out:
# array([[-8.0977079 , -5.52954702],
#        [ 1.91176144,  0.40634045],
#        [-4.55490993,  0.02920864],
#        [-9.73908486, -5.43581998]])

# %%
# Gerar o conjunto de dados
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
dataset_circles = noisy_circles[0]

# Mostrar os dados
plt.scatter(dataset_circles[:,0], dataset_circles[:,1], c=model_circle.labels_)
plt.show()

# %% [markdown]
# Os dados parecem estar agrupados corretamente? Tente fazer o mesmo procedimento com algoritmo de clusterização hieráquica, altera os parâmetros se for necessário.

# %%
### CODE HERE ###
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
dataset_circles = noisy_circles[0]

# Mostrar os dados
plt.scatter(dataset_circles[:,0], dataset_circles[:,1], c=clustering.labels_)
plt.show()

# %% [markdown]
# Mostre e análise o dendrograma do exemplo acima.

# %%
### CODE HERE ###
### CODE HERE ###

linkage = ["average", "ward", "complete"]

for i in linkage:
    if (i == 'average'):
        Z = hierarchy.average(dataset_circles)
    elif (i == 'complete'):
        Z = hierarchy.complete(dataset_circles)
    elif (i == 'ward'):
        Z = hierarchy.ward(dataset_circles)

    plt.figure(figsize=(15,8))
    plt.title("Dendrograma - linkage: " + str(i))
    dn = hierarchy.dendrogram(Z)

# %% [markdown]
# Qual a sua conclusão?

# %% [markdown]
# O kmeans consegue identificar corretamente os clusters, no entanto o noisy circles não consegue separar com precisão as labels.

# %% [markdown]
# # 2. DBSCAN

# %%
# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
dataset = np.dot(X, transformation)

# Mostrar os dados
plt.scatter(dataset[:,0], dataset[:,1])
plt.show()

# %% [markdown]
# Clusterize os dados usando clusterização Hierárquica

# %%
linkage = ["average", "ward", "complete"]

for i in linkage:
    if (i == 'average'):
        Z = hierarchy.average(dataset)
    elif (i == 'complete'):
        Z = hierarchy.complete(dataset)
    elif (i == 'ward'):
        Z = hierarchy.ward(dataset)

    plt.figure(figsize=(15,8))
    plt.title("Dendrograma - linkage: " + str(i))
    dn = hierarchy.dendrogram(Z)

# %% [markdown]
# Clusterize os dados usando o algoritmo DBSCAN.
# > https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import DBSCAN
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
def plot_db_clusters(db, X):
    core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
    core_samples_mask[db.core_sample_indices_] = True
    unique_labels = set(db.labels_)
    n_clusters = len(unique_labels) - (1 if -1 in labels else 0)
    colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = 'k'

        class_member_mask = (db.labels_ == k)

        xy = X[class_member_mask & core_samples_mask]
        plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
                 markeredgecolor='k', markersize=14)

        xy = X[class_member_mask & ~core_samples_mask]
        plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
                 markeredgecolor='k', markersize=6)

    plt.title('Número de Clusters: %d' % n_clusters)

# %%
dbscan = DBSCAN(eps=0.5, min_samples = 50)

# %%
db = dbscan.fit(X)

# %%
labels = set(db.labels_)
labels
# Out:
# {-1, 0, 1, 2}

# %%
print("Eps = 0.5")
plot_db_clusters(db,X)
# Out:
# Eps = 0.5

# %%
print("Eps = 0.65")
plot_db_clusters(db,X)
# Out:
# Eps = 0.65

# %% [markdown]
# Qual a sua conclusão?

# %% [markdown]
# Quando a distância entre os pontos é de 0.5 é gerado muito ruído ao redor dos clusters identificados. No entanto, quando o eps é 0.65 o dbscan consegue diminuir o número de ruído ao redor dos clusters.
